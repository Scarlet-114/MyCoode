# %% [markdown]
# # 6 Pandas的函数应用

# %%
import pandas as pd
import numpy as np
# Numpy ufunc 函数，randn跟的是维数
df = pd.DataFrame(np.random.randn(5,4) - 1)
print(df)

print(np.abs(df)) #绝对值
# Out:
#           0         1         2         3
# 0 -2.033743 -1.882977 -0.533294  0.317186
# 1 -1.086027 -0.586793 -3.160920 -1.266454
# 2 -1.815298 -1.128819 -2.562239 -0.742549
# 3 -0.366924 -1.617958 -2.951036 -1.340264
# 4 -0.217210 -0.375298 -0.616339 -1.084922
#           0         1         2         3
# 0  2.033743  1.882977  0.533294  0.317186
# 1  1.086027  0.586793  3.160920  1.266454
# 2  1.815298  1.128819  2.562239  0.742549
# 3  0.366924  1.617958  2.951036  1.340264
# 4  0.217210  0.375298  0.616339  1.084922

# %%
#apply默认作用在列上,x是每一列,因为axis=0
print(df.apply(lambda x : x.max()))
# Out:
# 0   -0.217210
# 1   -0.375298
# 2   -0.533294
# 3    0.317186
# dtype: float64

# %%
#apply作用在行上
print(df.apply(lambda x : x.max(), axis=1))
# Out:
# 0    0.317186
# 1   -0.586793
# 2   -0.742549
# 3   -0.366924
# 4   -0.217210
# dtype: float64

# %%
# 使用applymap应用到每个数据
print(df.map(lambda x : '%.2f' % x))
df.dtypes
# Out:
#        0      1      2      3
# 0  -2.03  -1.88  -0.53   0.32
# 1  -1.09  -0.59  -3.16  -1.27
# 2  -1.82  -1.13  -2.56  -0.74
# 3  -0.37  -1.62  -2.95  -1.34
# 4  -0.22  -0.38  -0.62  -1.08
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
type('%.2f' % 1.3456)
# Out:
# str

# %% [markdown]
# ## 6.4 索引排序（不重要）

# %%
# Series
print(np.random.randint(5, size=5))
print('-'*50)
s4 = pd.Series(range(10, 15), index = np.random.randint(5, size=5)) #索引随机生成
print(s4)
print('-'*50)
# 索引排序,sort_index返回一个新的排好索引的series
print(s4.sort_index())
print(s4)
# s4.loc[0:3]  loc索引值不唯一时直接报错
print(s4.iloc[0:3])
s4[0:3]  #默认用的位置索引
# Out:
# [4 2 3 4 2]
# --------------------------------------------------
# 0    10
# 2    11
# 2    12
# 1    13
# 3    14
# dtype: int64
# --------------------------------------------------
# 0    10
# 1    13
# 2    11
# 2    12
# 3    14
# dtype: int64
# 0    10
# 2    11
# 2    12
# 1    13
# 3    14
# dtype: int64
# 0    10
# 2    11
# 2    12
# dtype: int64
# 0    10
# 2    11
# 2    12
# dtype: int64

# %%
# s4.loc[1:2] #loc索引值唯一时可以切片

# %%
# DataFrame
df4 = pd.DataFrame(np.random.randn(5, 5),
                   index=np.random.randint(5, size=5),
                   columns=np.random.randint(5, size=5))
print(df4)
#轴零是行索引排序
df4_isort = df4.sort_index(axis=0, ascending=False)
print(df4_isort)
# Out:
#           1         0         0         3         3
# 2 -0.617581  0.856826  0.237405  0.586024  0.094512
# 1  0.614324 -0.243884 -0.396724 -1.200588  0.578545
# 3  2.147862 -1.814387 -1.265477  1.359299 -1.938455
# 1  0.614389 -0.320245  0.364803  0.099515 -0.615412
# 4 -1.353163  0.909200  0.343186  0.835050 -0.113928
#           1         0         0         3         3
# 4 -1.353163  0.909200  0.343186  0.835050 -0.113928
# 3  2.147862 -1.814387 -1.265477  1.359299 -1.938455
# 2 -0.617581  0.856826  0.237405  0.586024  0.094512
# 1  0.614324 -0.243884 -0.396724 -1.200588  0.578545
# 1  0.614389 -0.320245  0.364803  0.099515 -0.615412

# %%
#轴1是列索引排序
df4_isort = df4.sort_index(axis=1, ascending=True)
print(df4_isort)
# Out:
#           0         0         1         3         3
# 2  0.856826  0.237405 -0.617581  0.586024  0.094512
# 1 -0.243884 -0.396724  0.614324 -1.200588  0.578545
# 3 -1.814387 -1.265477  2.147862  1.359299 -1.938455
# 1 -0.320245  0.364803  0.614389  0.099515 -0.615412
# 4  0.909200  0.343186 -1.353163  0.835050 -0.113928

# %% [markdown]
# # 6.5 按值排序（机器学习，深度学习不重要，数据分析才需要）

# %%
# 按值排序,by后是column的值
import random
l=[random.randint(0,100) for i in range(24)] #生成24个随机数
df4 = pd.DataFrame(np.array(l).reshape(6,4)) #生成6行4列的dataframe
# print(df4) #查看数据,ndarray
# print('-'*50)
print(df4)
print('-'*50)
#按轴零排序，by后是列名,交换的是行
df4_vsort = df4.sort_values(by=3,axis=0, ascending=False) #寻找的是columns里的3,重要
print(df4_vsort)
# Out:
#     0   1   2   3
# 0  42  36  23  44
# 1  30  14  51  26
# 2  51  53  72  72
# 3  99  84   1  64
# 4  14  67  32  11
# 5  51  76  27  10
# --------------------------------------------------
#     0   1   2   3
# 2  51  53  72  72
# 3  99  84   1  64
# 0  42  36  23  44
# 1  30  14  51  26
# 4  14  67  32  11
# 5  51  76  27  10

# %%
#按轴1排序，by后行索引名，交换的是列
df4_vsort = df4.sort_values(by=3,axis=1, ascending=False) #寻找的是index里的3
print(df4_vsort)
# Out:
#     0   1   3   2
# 0  42  36  44  23
# 1  30  14  26  51
# 2  51  53  72  72
# 3  99  84  64   1
# 4  14  67  11  32
# 5  51  76  10  27

# %% [markdown]
# # 6.6 处理缺失数据（重要）

# %%
df_data = pd.DataFrame([np.random.randn(3), [1., 2., np.nan],
                       [np.nan, 4., np.nan], [1., 2., 3.]])
print(df_data.head())
# Out:
#           0         1         2
# 0 -2.069966  0.179373 -0.433364
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data.iloc[2,0]
# Out:
# np.float64(nan)

# %%
#isnull来判断是否有空的数据
print(df_data.isnull())
# Out:
#        0      1      2
# 0  False  False  False
# 1  False  False   True
# 2   True  False   True
# 3  False  False  False

# %%
#帮我计算df_data缺失率
print(df_data.isnull().sum()/len(df_data))
# Out:
# 0    0.25
# 1    0.00
# 2    0.50
# dtype: float64

# %% [markdown]
# ## 删除缺失数据

# %%
#默认一个样本，任何一个特征缺失，就删除
#inplace True是修改的是原有的df
#subset=[0]是指按第一列来删除,第一列有空值就删除对应的行 
print(df_data.dropna(subset=[0]))
# df_data
# Out:
#           0         1         2
# 0 -2.069966  0.179373 -0.433364
# 1  1.000000  2.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -2.069966  0.179373 -0.433364
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#用的不多，用在某个特征缺失太多时，才会进行删除
print(df_data.dropna(axis=1))  #某列由nan就删除该列
# Out:
#           1
# 0  0.179373
# 1  2.000000
# 2  4.000000
# 3  2.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -2.069966  0.179373 -0.433364
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %% [markdown]
# ## 填充缺失数据

# %%
#均值，中位数，众数填充

# %%
#给零列的空值填为-100，按特征（按列）去填充
print(df_data.iloc[:,0].fillna(-100.))
df_data
# Out:
# 0     -2.069966
# 1      1.000000
# 2   -100.000000
# 3      1.000000
# Name: 0, dtype: float64
#           0         1         2
# 0 -2.069966  0.179373 -0.433364
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#依次拿到每一列
for i in df_data.columns:
    print(df_data.loc[:,i])
# Out:
# 0   -2.069966
# 1    1.000000
# 2         NaN
# 3    1.000000
# Name: 0, dtype: float64
# 0    0.179373
# 1    2.000000
# 2    4.000000
# 3    2.000000
# Name: 1, dtype: float64
# 0   -0.433364
# 1         NaN
# 2         NaN
# 3    3.000000
# Name: 2, dtype: float64

# %%
df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除
# Out:
# C:\Users\11978\AppData\Local\Temp\ipykernel_15836\2218614896.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除
# 0     -2.069966
# 1      1.000000
# 2   -100.000000
# 3      1.000000
# Name: 0, dtype: float64

# %%
df_data.iloc[:,2]=df_data.iloc[:,2].fillna(df_data.iloc[:,2].mean()) #用均值填充空值

# %%
df_data
# Out:
#           0         1         2
# 0 -2.069966  0.179373 -0.433364
# 1  1.000000  2.000000  1.283318
# 2       NaN  4.000000  1.283318
# 3  1.000000  2.000000  3.000000
